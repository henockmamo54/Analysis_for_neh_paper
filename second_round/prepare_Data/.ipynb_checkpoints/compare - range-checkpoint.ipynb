# %%
import os
import math
import random
import warnings
import numpy as np
import pandas as pd 
from sklearn import metrics
from matplotlib import pyplot as plt

warnings.filterwarnings("ignore")

# %%
# data=pd.read_csv(r"C:\Workplace\Python\AnalysisForThePaper\NEH\second_round\D2O_NEH\res_theo_exp1.csv")
data=pd.read_csv(r"C:\Workplace\Python\AnalysisForThePaper\NEH\second_round\D2O_NEH\sim_all_no_noise.csv")
data.columns=['pep','a','b','cpxt','pxt','neh','cneh','b1','b2','b3','a1','a2','delta1','delta2','rmse',
             'a20','a21','a22','a23',
             'b20','b21','b22','b23','b24','b25','i0','i1','i2']
data=data[data.pxt<=0.06]
data=data.drop_duplicates()
print(data.shape)
# Out:
# (169271, 28)

# %%
# data2.i2.min()

# %%
# data=pd.read_csv(r"C:\Workplace\Python\AnalysisForThePaper\NEH\second_round\D2O_NEH\res_theo_exp1.csv")
data2=pd.read_csv(r"C:\Workplace\Python\AnalysisForThePaper\NEH\second_round\D2O_NEH\sim_i2_noise.csv")
data2.columns=['pep','a','b','cpxt','pxt','neh','cneh','b1','b2','b3','a1','a2','delta1','delta2','rmse',
             'a20','a21','a22','a23',
             'b20','b21','b22','b23','b24','b25','i0','i1','i2']
data2=data2[data2.pxt<=0.06]
data2=data2.drop_duplicates()
print(data2.shape)

temp_merged=data.merge(data2,on=['pep','pxt'])
print(temp_merged.shape)
g=temp_merged[100*abs(temp_merged.cpxt_y-temp_merged.pxt)/temp_merged.pxt <=15]
b=temp_merged[100*abs(temp_merged.cpxt_y-temp_merged.pxt)/temp_merged.pxt >15]
print(g.shape[0],b.shape[0])
# Out:
# (169271, 28)
# (169271, 54)
# 8255 161016

# %%
e_e=abs(g.i2_x-g.i2_y)
be_e=abs(b.i2_x-b.i2_y)

print(min(e_e),max(e_e))
print(min(be_e),max(be_e))
# Out:
# 3.415714699972483e-08 0.0010194546070340094
# 3.5614419620078053e-06 0.02384045705327803

# %%
test=b[abs(b.i2_x-b.i2_y)<0.0010194546070340094]
test=test.reset_index(drop=True)
test.head()
# Out:
#           pep       a_x       b_x  cpxt_x     pxt  neh_x  cneh_x      b1_x  \
# 0  DSTLIMQLLR -0.065894  0.000534  0.0081  0.0081     16    16.0 -0.093057
# 1  DSTLIMQLLR -0.082496  0.000833  0.0101  0.0101     16    16.0 -0.118764
# 2  DSTLIMQLLR -0.220246  0.005748  0.0261  0.0261     16    16.0 -0.365346
# 3  DSTLIMQLLR -0.229155  0.006210  0.0271  0.0271     16    16.0 -0.383263
# 4  DSTLIMQLLR -0.256100  0.007709  0.0301  0.0301     16    16.0 -0.438853
#
#        b2_x      b3_x  ...     a23_y     b20_y     b21_y     b22_y     b23_y  \
# 0  0.102146 -0.008555  ... -0.065350 -0.091706  0.000027  0.102146 -0.008537
# 1  0.132946 -0.013348  ... -0.081650 -0.118433  0.000033  0.132946 -0.013327
# 2  0.463079 -0.091984  ... -0.214463 -0.364310  0.000087  0.463079 -0.091946
# 3  0.488843 -0.099369  ... -0.222909 -0.385645  0.000090  0.488843 -0.099331
# 4  0.569900 -0.123338  ... -0.248352 -0.441815  0.000101  0.569900 -0.123299
#
#       b24_y     b25_y      i0_y      i1_y      i2_y
# 0  0.000003  0.000020  0.426094  0.333162  0.160495
# 1  0.000004  0.000025  0.412552  0.336023  0.166422
# 2  0.000029  0.000067  0.317855  0.343323  0.206387
# 3  0.000031  0.000069  0.312672  0.343007  0.209694
# 4  0.000038  0.000077  0.297595  0.341610  0.216301
#
# [5 rows x 54 columns]

# %%
test.loc[0,['pxt','delta2_x','delta1_x',"i1_x","i0_x","i2_x"]]
# Out:
# pxt           0.0081
# delta2_x    0.093098
# delta1_x    0.130699
# i1_x        0.333162
# i0_x        0.426094
# i2_x        0.161082
# Name: 0, dtype: object

# %%
test.loc[0,['cpxt_y','delta2_y','delta1_y',"i1_y","i0_y","i2_y"]]
# Out:
# cpxt_y      0.028408
# delta2_y    0.091721
# delta1_y    0.130699
# i1_y        0.333162
# i0_y        0.426094
# i2_y        0.160495
# Name: 0, dtype: object

# %%
list(1 +(0.5/( (test.delta2_x/test.delta1_x) - (test.i1_x/test.i0_x) + (0.5*test.delta1_x) - 0.5)))[0]
# Out:
# 0.008408919313862673

# %%
list(1 +(0.5/( (test.delta2_y/test.delta1_y) - (test.i1_y/test.i0_y) + (0.5*test.delta1_y) - 0.5)))[0]
# Out:
# 0.028710239228962986

# %%
[x for x in (1+0.5/((test.delta2_x/test.delta1_x) - (test.i1_x/test.i0_x) + (0.5*test.delta1_x) -0.5))-test.pxt if  x >0.001]
# Out:
# []

# %%
[y for y in (1+0.5/((test.delta2_y/test.delta1_y) - (test.i1_y/test.i0_y) + (0.5*test.delta1_y) -0.5))-test.pxt if  y >0.001]
# Out:
# [0.020610239228962986,
#  0.004656216765422381,
#  0.005240379159555785,
#  0.009240391382286845,
#  0.007888671961126893,
#  0.005016941742544089,
#  0.009004630864912905,
#  0.022808136812875184,
#  0.01426285793924642,
#  0.013528776565370139,
#  0.02780460373184023,
#  0.015890266961389538,
#  0.01962525536663994,
#  0.015655950328949612,
#  0.013962268578878285,
#  0.004000135152688274,
#  0.01705683476338739,
#  0.013512004769586715,
#  0.013504250800498246,
#  0.00856224918662099,
#  0.012538699000378621,
#  0.0050231307416905985,
#  0.01367592024795316,
#  0.0015771331072920135,
#  0.008014252117195989,
#  0.01230504586189618,
#  0.00633681575530454,
#  0.011437532492108111,
#  0.011111845934432742,
#  0.01058166813401977,
#  0.01271610356623897,
#  0.0023712741210594112,
#  0.005936878346645796,
#  0.012622101097717218,
#  0.007115649619001574,
#  0.00997212882956323,
#  0.020105987999945923,
#  0.011945354546085266,
#  0.013455082244127649,
#  0.01124719036768852,
#  0.007490087441809585,
#  0.007748301085260943,
#  0.03290213977003364,
#  0.012191762304870183,
#  0.011056553648872931,
#  0.00874125383764049,
#  0.07904142018148873,
#  0.032678163007250675,
#  0.019465403718965765,
#  0.015633892457022625,
#  0.028339654821045543,
#  0.02391348737673507,
#  0.026123074029189605,
#  0.031850671792569944,
#  0.01066605249958056,
#  0.009058373290480794,
#  0.010171797132474757,
#  0.006929341195710113,
#  0.015270671650767377,
#  0.06010184796227468,
#  0.0034544134096576827,
#  0.015907366390852114,
#  0.008660895988236418,
#  0.06019523244974533,
#  0.011175708455825942,
#  0.009170691417026762,
#  0.012712794036586886,
#  0.013567657881842478,
#  0.013239501880818128,
#  0.01700022154053016,
#  0.0132276525548021,
#  0.014989342830343179,
#  0.14033428057079878,
#  0.08520644921056873,
#  0.0044330719658538485,
#  0.01872845171496129,
#  0.014708547398804374,
#  0.02354916507706428,
#  0.023916394222276344,
#  0.031234060733234127,
#  0.009126150590933392,
#  0.02570278364931922,
#  0.021931739941921557,
#  0.01749652953449734,
#  0.003569957439126692,
#  0.023382137113084026,
#  0.009966838112168495,
#  0.01852342529855313,
#  0.01035255258348048,
#  0.016088489025083412,
#  0.011403453530165803,
#  0.010805307888027364,
#  0.014965581323810234,
#  0.0014091753486621334,
#  0.004603441333412072,
#  0.01179343410453761,
#  0.01052603384697959,
#  0.008361106273171014,
#  0.009652547350145979,
#  0.016630111687423343,
#  ...]

# %%
#over all error
g_s=((g.delta2_x/g.delta1_x) - (g.i1_x/g.i0_x) + (0.5*g.delta1_x))
g_t=((g.delta2_y/g.delta1_y) - (g.i1_y/g.i0_y) + (0.5*g.delta1_y))
e_e=abs(g_s-g_t)
b_s=((b.delta2_x/b.delta1_x) - (b.i1_x/b.i0_x) + (0.5*b.delta1_x))
b_t=((b.delta2_y/b.delta1_y) - (b.i1_y/b.i0_y) + (0.5*b.delta1_y))
be_e=abs(b_s-b_t)
print(min(e_e),max(e_e))
print(min(be_e),max(be_e))
# Out:
# 9.123728620108462e-07 0.004979686096499625
# 0.00019104591712757434 2344.189303665867

# %%
#i0 
data2=pd.read_csv(r"C:\Workplace\Python\AnalysisForThePaper\NEH\second_round\D2O_NEH\I0_noise.csv")
data2.columns=['pep','a','b','cpxt','pxt','neh','cneh','b1','b2','b3','a1','a2','delta1','delta2','rmse',
             'a20','a21','a22','a23',
             'b20','b21','b22','b23','b24','b25','i0','i1']
data2=data2[data2.pxt<=0.06]
data2=data2.drop_duplicates(['pep','pxt'])
print(data2.shape)

temp_merged=data.merge(data2,on=['pep','pxt'])
print(temp_merged.shape)
g=temp_merged[100*abs(temp_merged.cpxt_y-temp_merged.pxt)/temp_merged.pxt <=15]
b=temp_merged[100*abs(temp_merged.cpxt_y-temp_merged.pxt)/temp_merged.pxt >15]
print(g.shape[0],b.shape[0])
# Out:
# (2869, 27)
# (2869, 52)
# 154 2715

# %%
#over all error
e_e=abs(g.i0_x-g.i0_y)
be_e=abs(b.i0_x-b.i0_y)

print(min(e_e),max(e_e))
print(min(be_e),max(be_e))
# Out:
# 2.1995098130334068e-07 0.0012157675427599823
# 4.06941852170023e-05 0.01722255603275799

# %%
#i1
data2=pd.read_csv(r"C:\Workplace\Python\AnalysisForThePaper\NEH\second_round\D2O_NEH\I1_noise.csv")
data2.columns=['pep','a','b','cpxt','pxt','neh','cneh','b1','b2','b3','a1','a2','delta1','delta2','rmse',
             'a20','a21','a22','a23',
             'b20','b21','b22','b23','b24','b25','i0','i1']
data2=data2[data2.pxt<=0.06]
data2=data2.drop_duplicates(['pep','pxt'])
print(data2.shape)

temp_merged=data.merge(data2,on=['pep','pxt'])
print(temp_merged.shape)
g=temp_merged[100*abs(temp_merged.cpxt_y-temp_merged.pxt)/temp_merged.pxt <=15]
b=temp_merged[100*abs(temp_merged.cpxt_y-temp_merged.pxt)/temp_merged.pxt >15]
print(g.shape[0],b.shape[0])
# Out:
# (2869, 27)
# (2869, 52)
# 99 2770

# %%
#over all error
e_e=abs(g.i1_x-g.i1_y)
be_e=abs(b.i1_x-b.i1_y)

print(min(e_e),max(e_e))
print(min(be_e),max(be_e))
# Out:
# 4.816064440027468e-07 0.0006643912895960002
# 3.672011246970419e-05 0.021733640618808003

# %%
# plt.figure(figsize=(10,5))
# plt.subplot(1,2,1)
# plt.scatter(g.pxt,g.cpxt_y,s=10,c='r') 
# plt.subplot(1,2,2)
# plt.scatter(b.pxt,b.cpxt_y,s=10,c='r')

# %%
# x=abs(g.delta2_x-g.delta2_y)
# print(min(x),max(x))
# x=abs(b.delta2_x-b.delta2_y)
# print(min(x),max(x))

# %%
# x=abs(g.delta1_x-g.delta1_y)
# print(min(x),max(x))
# x=abs(b.delta1_x-b.delta1_y)
# print(min(x),max(x))

# %%
# x=abs(g.delta2_x/g.delta1_x-g.delta2_y/g.delta1_y)
# print(min(x),max(x))
# # plt.hist(x,bins=100)
# # plt.show()
# x=abs(b.delta2_x/b.delta1_x-b.delta2_y/b.delta1_y)
# print(min(x),max(x))
# # plt.hist(x,bins=100)
# # plt.show()

# %%
# [i for i in x  if i<0.16838165050626408]

# %%
# 1 +(0.5/( (g.delta2_x/g.delta1_x) - (g.i1_x/g.i0_x) + (0.5*g.delta1_x) - 0.5))

# %%
# g_s=((g.delta2_x/g.delta1_x) - (g.i1_x/g.i0_x) + (0.5*g.delta1_x))
# g_t=((g.delta2_y/g.delta1_y) - (g.i1_y/g.i0_y) + (0.5*g.delta1_y))
# e_e=abs(g_s-g_t)

# %%
# b_s=((b.delta2_x/b.delta1_x) - (b.i1_x/b.i0_x) + (0.5*b.delta1_x))
# b_t=((b.delta2_y/b.delta1_y) - (b.i1_y/b.i0_y) + (0.5*b.delta1_y))
# be_e=abs(b_s-b_t)

# %%
print(min(e_e),max(e_e))
# Out:
# 0.00012607019533972252 0.0037479360106799087

# %%
print(min(be_e),max(be_e))
# Out:
# 0.003841580093199126 13.858805486251503

# %%
plt.scatter(data.pxt,data.cpxt,s=10,c='r') 
# plt.scatter(temp.delta1,temp.delta2,s=10,c='r')

# %%
plt.scatter([float(x) for x in data.cpxt.astype('float')],data.cpxt.astype('float'))

# %%
temp=data2[100*abs(data2.cpxt-data2.pxt)/data2.pxt >10]
plt.scatter(temp.delta1,temp.delta2,s=10,c='r') 
temp[['delta1','delta2','i0','i1','pxt','cpxt']].head()
# Out:
#        delta1    delta2        i0        i1    pxt      cpxt
# 0    0.710254  0.734667  0.295765  0.402670  0.046 -0.059754
# 100  1.065204  1.207209  0.240781  0.410452  0.046  0.071641
# 200  1.570403  2.804428  0.151929  0.363256  0.046 -0.563223
# 300  1.591616  2.923604  0.134594  0.371183  0.046  0.199901
# 400  3.373952  5.914234  0.082097  0.372046  0.046  0.685735

# %%
temp=data[100*abs(data.cpxt-data.pxt)/data.pxt <10]
plt.scatter(temp.delta1,temp.delta2,s=10,c='r') 
temp[['delta1','delta2','i0','i1','pxt','cpxt']].head()
# Out:
#        delta1    delta2        i0        i1    pxt   cpxt
# 0    0.771735  0.781608  0.286575  0.407777  0.046  0.046
# 100  1.109369  1.297823  0.233213  0.407851  0.046  0.046
# 200  1.784636  3.013549  0.142747  0.371884  0.046  0.046
# 300  1.881103  3.917342  0.114771  0.349741  0.046  0.046
# 400  2.122270  4.657698  0.103386  0.339116  0.046  0.046

# %%
temp=data[(100*abs(data.cpxt-data.pxt)/data.pxt > 10) & (100*abs(data.cpxt-data.pxt)/data.pxt < 20)]
plt.scatter(temp.delta1,temp.delta2,s=10,c='r') 
temp[['delta1','delta2','i0','i1','pxt','cpxt']].head()
# Out:
# Empty DataFrame
# Columns: [delta1, delta2, i0, i1, pxt, cpxt]
# Index: []

# %%
# temp[['delta1','delta2','i0','i1','pxt','cpxt']].head()

# %%
data2=pd.read_csv(r"C:\Workplace\Python\AnalysisForThePaper\NEH\second_round\D2O_NEH\res_theo_22.csv")
data2.columns=['pep','a','b','cpxt','pxt','neh','cneh','b1','b2','b3','a1','a2','delta1','delta2','rmse',
             'a20','a21','a22','a23',
             'b20','b21','b22','b23','b24','b25','i0','i1']
data2=data2[data2.pxt<=0.06]

# data2.a=data2.a20 +data2.a21 +data2.a22 +data2.a23 

# data2.pxt=[(abs(x)) for x in data2.pxt]
# data2.cpxt=[(abs(x)) for x in data2.cpxt]
# data2.a=[(abs(x)) for x in data2.a]
# data2.a20=[(abs(x)) for x in data2.a20]
# data2.a21=[(abs(x)) for x in data2.a21]
# data2.a22=[(abs(x)) for x in data2.a22]
# data2.a23=[(abs(x)) for x in data2.a23]

data2=data2.drop_duplicates()
print(data2.shape)
# Out:
# (169271, 27)

# %%
pep=list(np.unique(data.pep))
len(pep)
# Out:
# 2869

# %%
# index=10
# temp1=data[data.pep==pep[index]]
# temp2=data2[data2.pep==pep[index]]
# # temp2=temp1
# print(pep[index],temp1.shape[0],temp2.shape[0])

# plt.figure(figsize=(15,10))
# plt.subplot(2,3,1)
# plt.title('pxt')
# plt.scatter(temp.pxt,temp.cpxt_y,s=10,c='k')
# plt.plot(temp.pxt,temp.pxt,c='r',ls="-.")
# plt.subplot(2,3,2)
# plt.title('a')
# plt.scatter(temp.a_x,temp.a_y,s=10,c='k')
# plt.subplot(2,3,3)
# plt.title('a1')
# plt.scatter(temp.a20_x,temp.a20_y,s=10,c='k')
# plt.subplot(2,3,4)
# plt.title('a2')
# plt.scatter(temp.a21_x,temp.a21_y,s=10,c='k')
# plt.subplot(2,3,5)
# plt.title('a3')
# plt.scatter(temp.a22_x,temp.a22_y,s=10,c='k')
# plt.subplot(2,3,6)
# plt.title('a4')
# plt.scatter(temp.a23_x,temp.a23_y,s=10,c='k')
# plt.show()

# plt.figure(figsize=(15,10))
# plt.subplot(2,3,1)
# plt.title('a')
# plt.scatter(temp.pxt,temp.a_x,s=10,c='g')
# plt.scatter(temp.pxt,temp.a_y,s=10,c='r')
# plt.subplot(2,3,2)
# plt.title('a1')
# plt.scatter(temp.pxt,temp.a20_x,s=10,c='g')
# plt.scatter(temp.pxt,temp.a20_y,s=10,c='r')
# plt.subplot(2,3,3)
# plt.title('a2')
# plt.scatter(temp.pxt,temp.a21_x,s=10,c='g')
# plt.scatter(temp.pxt,temp.a21_y,s=10,c='r')
# plt.subplot(2,3,4)
# plt.title('a3')
# plt.scatter(temp.pxt,temp.a22_x,s=10,c='g')
# plt.scatter(temp.pxt,temp.a22_y,s=10,c='r')
# plt.subplot(2,3,5)
# plt.title('a4')
# plt.scatter(temp.pxt,temp.a23_x,s=10,c='g')
# plt.scatter(temp.pxt,temp.a23_y,s=10,c='r')

# %%
# temp_merge=temp1.merge(temp2, on=['pep','pxt'])
# temp_merge['pxt_acc']=100*abs(temp_merge.cpxt_y-temp_merge.pxt)/temp_merge.pxt

# temp=temp_merge[temp_merge.pxt_acc<20]
# plt.figure(figsize=(15,10))
# plt.subplot(2,3,1)
# plt.title('pxt')
# plt.scatter(temp.pxt,temp.cpxt_y,s=10,c='k')
# plt.plot(temp.pxt,temp.pxt,c='r',ls="-.")
# plt.subplot(2,3,2)
# plt.title('a')
# plt.scatter(temp.a_x,temp.a_y,s=10,c='k')
# plt.subplot(2,3,3)
# plt.title('a1')
# plt.scatter(temp.a20_x,temp.a20_y,s=10,c='k')
# plt.subplot(2,3,4)
# plt.title('a2')
# plt.scatter(temp.a21_x,temp.a21_y,s=10,c='k')
# plt.subplot(2,3,5)
# plt.title('a3')
# plt.scatter(temp.a22_x,temp.a22_y,s=10,c='k')
# plt.subplot(2,3,6)
# plt.title('a4')
# plt.scatter(temp.a23_x,temp.a23_y,s=10,c='k')
# plt.show()
# print('===================================================')

# temp=temp_merge[temp_merge.pxt_acc>20]

# plt.figure(figsize=(15,10))
# plt.subplot(2,3,1)
# plt.title('pxt')
# plt.scatter(temp.pxt,temp.cpxt_y,s=10,c='k')
# plt.plot(temp.pxt,temp.pxt,c='r',ls="-.")
# plt.subplot(2,3,2)
# plt.title('a')
# plt.scatter(temp.a_x,temp.a_y,s=10,c='k')
# plt.subplot(2,3,3)
# plt.title('a1')
# plt.scatter(temp.a20_x,temp.a20_y,s=10,c='k')
# plt.subplot(2,3,4)
# plt.title('a2')
# plt.scatter(temp.a21_x,temp.a21_y,s=10,c='k')
# plt.subplot(2,3,5)
# plt.title('a3')
# plt.scatter(temp.a22_x,temp.a22_y,s=10,c='k')
# plt.subplot(2,3,6)
# plt.title('a4')
# plt.scatter(temp.a23_x,temp.a23_y,s=10,c='k')
# plt.show()
# print('===================================================')

# plt.figure(figsize=(15,10))
# plt.subplot(2,3,1)
# plt.title('a')
# plt.scatter(temp_merge.pxt,temp_merge.a_x,s=10,c='g')
# plt.scatter(temp.pxt,temp.a_y,s=10,c='r')
# plt.subplot(2,3,2)
# plt.title('a1')
# plt.scatter(temp_merge.pxt,temp_merge.a20_x,s=10,c='g')
# plt.scatter(temp.pxt,temp.a20_y,s=10,c='r')
# plt.subplot(2,3,3)
# plt.title('a2')
# plt.scatter(temp_merge.pxt,temp_merge.a21_x,s=10,c='g')
# plt.scatter(temp.pxt,temp.a21_y,s=10,c='r')
# plt.subplot(2,3,4)
# plt.title('a3')
# plt.scatter(temp_merge.pxt,temp_merge.a22_x,s=10,c='g')
# plt.scatter(temp_merge.pxt,temp_merge.a22_y,s=10,c='r')
# plt.subplot(2,3,5)
# plt.title('a4')
# plt.scatter(temp_merge.pxt,temp_merge.a22_x,s=10,c='g')
# plt.scatter(temp_merge.pxt,temp_merge.a22_y,s=10,c='r')

# %%
index=1000

while index < len(pep):
    temp1=data[data.pep==pep[index]]
    temp2=data2[data2.pep==pep[index]]

    temp_merge=temp1.merge(temp2, on=['pep','pxt'])
    temp_merge['pxt_acc']=100*abs(temp_merge.cpxt_y-temp_merge.pxt)/temp_merge.pxt
    

#     temp=temp_merge#[temp_merge.pxt_acc<20]
# #     if temp.shape[0]<10:
# #         index+=1
# #         continue
#     print(f"=================================={pep[index]}========================")
#     plt.figure(figsize=(15,15))
#     plt.subplot(3,3,1)
#     plt.title('pxt')
#     plt.scatter(temp.pxt,temp.cpxt_y,s=10,c='k')
#     plt.plot(temp.pxt,temp.cpxt_x,c='r',ls="-.")
#     plt.subplot(3,3,2)
#     plt.title('b')
#     plt.scatter(temp.b_x,temp.b_y,s=10,c='k')
#     plt.plot(temp.b_x,temp.b_x,c='r',ls="-.")
#     plt.subplot(3,3,3)
#     plt.title('b1')
#     plt.scatter(temp.b20_x,temp.b20_y,s=10,c='k')
#     plt.plot(temp.b20_x,temp.b20_x,c='r',ls="-.")
#     plt.subplot(3,3,4)
#     plt.title('b2')
#     plt.scatter(temp.b21_x,temp.b21_y,s=10,c='k')
#     plt.plot(temp.b21_x,temp.b21_x,c='r',ls="-.")
#     plt.subplot(3,3,5)
#     plt.title('b3')
#     plt.scatter(temp.b22_x,temp.b22_y,s=10,c='k')
#     plt.plot(temp.b22_x,temp.b22_x,c='r',ls="-.")
#     plt.subplot(3,3,6)
#     plt.title('b4')
#     plt.scatter(temp.b23_x,temp.b23_y,s=10,c='k')
#     plt.plot(temp.b23_x,temp.b23_x,c='r',ls="-.")
#     plt.subplot(3,3,7)
#     plt.title('b5')
#     plt.scatter(temp.b24_x,temp.b24_y,s=10,c='k')
#     plt.plot(temp.b24_x,temp.b24_x,c='r',ls="-.")
#     plt.subplot(3,3,8)
#     plt.title('b6')
#     plt.scatter(temp.b25_x,temp.b25_y,s=10,c='k')
#     plt.plot(temp.b25_x,temp.b25_x,c='r',ls="-.")
#     plt.subplot(3,3,9)
#     plt.title('b')
#     plt.scatter(temp.b_x,(temp.b20_y+temp.b21_y+temp.b22_y+temp.b23_y+temp.b24_y+temp.b25_y),s=10,c='k')
#     plt.show()
#     print('===================================================')
    
#     plt.figure(figsize=(15,15))
#     plt.subplot(3,3,1)
#     plt.title('pxt')
#     plt.plot(temp_merge.pxt,temp_merge.cpxt_x,c='g',ls='-.',alpha=0.75) 
#     plt.scatter(temp.pxt,temp.cpxt_y,s=10,c='r')
#     plt.subplot(3,3,2)
#     plt.title('b')
#     plt.plot(temp_merge.pxt,temp_merge.b_x,c='g',ls='-.',alpha=0.75)
#     plt.scatter(temp.pxt,temp.b_y,s=10,c='r') 
#     plt.subplot(3,3,3)
#     plt.title('b1')
#     plt.plot(temp_merge.pxt,temp_merge.b20_x,c='g',ls='-.',alpha=0.75)
#     plt.scatter(temp.pxt,temp.b20_y,s=10,c='r') 
#     plt.subplot(3,3,4)
#     plt.title('b2')
#     plt.plot(temp_merge.pxt,temp_merge.b21_x,c='g',ls='-.',alpha=0.75)
#     plt.scatter(temp.pxt,temp.b21_y,s=10,c='r') 
#     plt.subplot(3,3,5)
#     plt.title('b3')
#     plt.plot(temp_merge.pxt,temp_merge.b22_x,c='g',ls='-.',alpha=0.75)
#     plt.scatter(temp.pxt,temp.b22_y,s=10,c='r') 
#     plt.subplot(3,3,6)
#     plt.title('b4')
#     plt.plot(temp_merge.pxt,temp_merge.b23_x,c='g',ls='-.',alpha=0.75)
#     plt.scatter(temp.pxt,temp.b23_y,s=10,c='r') 
#     plt.subplot(3,3,7)
#     plt.title('b5')
#     plt.plot(temp_merge.pxt,temp_merge.b24_x,c='g',ls='-.',alpha=0.75)
#     plt.scatter(temp.pxt,temp.b24_y,s=10,c='r') 
#     plt.subplot(3,3,8)
#     plt.title('b6')
#     plt.plot(temp_merge.pxt,temp_merge.b25_x,c='g',ls='-.',alpha=0.75)
#     plt.scatter(temp.pxt,temp.b25_y,s=10,c='r') 
#     plt.subplot(3,3,9)
#     plt.title('b')
#     plt.plot(temp_merge.pxt,temp_merge.b_x,c='g',ls='-.',alpha=0.75)
#     plt.scatter(temp.pxt,
#                 (
#                     temp.b20_y+
#                  temp.b21_y+
#                  temp.b22_y+
#                  temp.b23_y+
#                  temp.b24_y+
#                  temp.b25_y
#                 )
#                 ,s=10,c='r')
#     plt.show()


    
    print('===================================================')
    plt.figure(figsize=(15,7))
    plt.subplot(1,2,1)
#     plt.title('real')
    plt.plot(temp_merge.delta1_x,temp_merge.delta2_x,c='g',ls='-.',alpha=0.75)    
    plt.scatter(temp_merge.delta1_y,temp_merge.delta2_y,c='r',alpha=0.75)
#     plt.scatter(temp.pxt,temp.b23_y,s=10,c='r') 
    
    plt.subplot(1,2,2)
#     plt.title('noise')
#     plt.scatter(temp_merge.delta1_y,temp_merge.delta2_y,c='g',ls='-.',alpha=0.75)
    plt.plot(temp_merge.pxt,temp_merge.cpxt_x,ls='-.',c='g') 
    plt.scatter(temp_merge.pxt,temp_merge.cpxt_y,s=10,c='r') 
    
    print('===================================================')
    
    
    
    index+=1
    print("********************************************************\n")
    break
# Out:
# ===================================================
# ===================================================
# ********************************************************

# %%
test=1+ 0.5/(temp_merge.delta2_x/temp_merge.delta1_x + 0.5*temp_merge.delta1_x - 0.5 - temp_merge.i1_x/temp_merge.i0_x)
[x for x in abs(temp_merge.pxt-test) if x >0.001]
# Out:
# []

# %%
test=1+ 0.5/(temp_merge.delta2_y/temp_merge.delta1_y + 0.5*temp_merge.delta1_y - 0.5 - temp_merge.i1_y/temp_merge.i0_y)
[x for x in abs(temp_merge.pxt-test) if x >0.001]
# Out:
# [0.1890327153539052,
#  0.182929075647003,
#  0.30231075229587134,
#  0.30359193125830053,
#  0.09999090300855384,
#  0.35880192536557964,
#  0.025648921005408172,
#  0.24183962273452353,
#  0.2810330355849373,
#  0.10285958456809174,
#  0.02533582346739982,
#  0.038716473862273615,
#  0.1362197564009301,
#  0.33288382140263906,
#  0.15808039381038996,
#  0.014396980349526082,
#  0.44114291073598,
#  0.0463835463118607,
#  0.1640577572604105,
#  0.19629699532620148,
#  0.18915696999696807,
#  0.12065060866170518,
#  0.006375157805846066,
#  0.22137518921465094,
#  0.07447362599475903,
#  0.05642742089813167,
#  0.13091869099076792,
#  0.037404312620068395,
#  0.17691468635690744,
#  0.278596772785066,
#  0.20479210873214773,
#  0.07092242753211916,
#  0.13750689819036474,
#  0.03767558807202611,
#  0.25410757695326147,
#  0.22222917257597155,
#  0.014129595732307078,
#  0.18872469086396662,
#  0.4003410716398558,
#  0.22552243423686594,
#  0.20135212410967332,
#  0.23279455995092738,
#  0.13209203393348887,
#  0.041305087775145605,
#  0.13290560674532362,
#  0.1834386335355183,
#  1.3989170021972526,
#  0.2666375831030631,
#  0.16688900802612153,
#  0.03847474056186936,
#  0.004120244985267009,
#  0.4472589896205143,
#  0.2603023567074812,
#  0.1250518698107241,
#  0.2616588408218214,
#  0.08404734452852565,
#  0.030681822170689974,
#  0.13239203431637064,
#  0.19729457538863354]

# %%
plt.scatter(temp.pxt,
                (
                    temp.b20_y+
#                  temp.b21_y+
                 temp.b22_y+
                 temp.b23_y #+
#                  temp.b24_y+
#                  temp.b25_y
                )
                ,s=10,c='r')


plt.plot(temp_merge.pxt,temp_merge.b_x,c='g',ls='-.',alpha=0.75)

# %%
plt.scatter((
#                     temp.b20_x#+ 
                 temp.b22_x+
                 temp.b23_x  
                )
    ,
                (
#                     temp.b20_y#+ 
                 temp.b22_y+
                 temp.b23_y  
                )
                ,s=10,c='r')

# %%
plt.scatter((
                    temp.b20_x#+ 
#                  temp.b22_x+
#                  temp.b23_x  
                )
    ,
                (
                    temp.b20_y#+ 
#                  temp.b22_y+
#                  temp.b23_y  
                )
                ,s=10,c='r')

# %%
plt.scatter((
                    temp.b20_x+ 
                 temp.b22_x+
                 temp.b23_x  
                )
    ,
                (
                    temp.b20_y+ 
                 temp.b22_y+
                 temp.b23_y  
                )
                ,s=10,c='r')

# %%
i=20#len(temp.b20_x)-1
print(temp.b20_x[i],temp.b20_y[i])
print(temp.b22_x[i],temp.b22_y[i])
print(temp.b23_x[i],temp.b23_y[i])
print(temp.b_x[i],temp.b_y[i])
# Out:
# -0.455486618364213 -0.436859009221335
# 0.572983941474853 0.520087834501773
# -0.112453808293617 -0.0977676532094222
# 0.0051131293781575 -0.0144761259983288
