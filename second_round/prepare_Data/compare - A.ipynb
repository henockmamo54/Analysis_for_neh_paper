# %%
import os
import math
import random
import warnings
import numpy as np
import pandas as pd 
from sklearn import metrics
from matplotlib import pyplot as plt

warnings.filterwarnings("ignore")

# %%
data=pd.read_csv(r"C:\Workplace\Python\AnalysisForThePaper\NEH\second_round\D2O_NEH\res_theo_1.csv")
data.columns=['pep','a','b','cpxt','pxt','neh','cneh','b1','b2','b3','a1','a2','delta1','delta2','rmse',
             'a20','a21','a22','a23']
data=data[data.pxt<=0.06]
# data.a=data.a20 +data.a21 +data.a22 +data.a23 

# data.pxt=[math.log(abs(x)) for x in data.pxt]
# data.cpxt=[math.log(abs(x)) for x in data.cpxt]
# data.a=[math.log(abs(x)) for x in data.a]
# data.a20=[math.log(abs(x)) for x in data.a20]
# data.a21=[math.log(abs(x)) for x in data.a21]
# data.a22=[math.log(abs(x)) for x in data.a22]
# data.a23=[math.log(abs(x)) for x in data.a23]

data=data.drop_duplicates()
print(data.shape)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [2], in <cell line: 2>()
#       1 data=pd.read_csv(r"C:\Workplace\Python\AnalysisForThePaper\NEH\second_round\D2O_NEH\res_theo_1.csv")
# ----> 2 data.columns=['pep','a','b','cpxt','pxt','neh','cneh','b1','b2','b3','a1','a2','delta1','delta2','rmse',
#       3              'a20','a21','a22','a23']
#       4 data=data[data.pxt<=0.06]
#       5 # data.a=data.a20 +data.a21 +data.a22 +data.a23
#       6
#       7 # data.pxt=[math.log(abs(x)) for x in data.pxt]
#    (...)
#      12 # data.a22=[math.log(abs(x)) for x in data.a22]
#      13 # data.a23=[math.log(abs(x)) for x in data.a23]
#
# File ~\.conda\envs\myenv\lib\site-packages\pandas\core\generic.py:5596, in NDFrame.__setattr__(self, name, value)
#    5594 try:
#    5595     object.__getattribute__(self, name)
# -> 5596     return object.__setattr__(self, name, value)
#    5597 except AttributeError:
#    5598     pass
#
# File ~\.conda\envs\myenv\lib\site-packages\pandas\_libs\properties.pyx:70, in pandas._libs.properties.AxisProperty.__set__()
#
# File ~\.conda\envs\myenv\lib\site-packages\pandas\core\generic.py:769, in NDFrame._set_axis(self, axis, labels)
#     767 def _set_axis(self, axis: int, labels: Index) -> None:
#     768     labels = ensure_index(labels)
# --> 769     self._mgr.set_axis(axis, labels)
#     770     self._clear_item_cache()
#
# File ~\.conda\envs\myenv\lib\site-packages\pandas\core\internals\managers.py:214, in BaseBlockManager.set_axis(self, axis, new_labels)
#     212 def set_axis(self, axis: int, new_labels: Index) -> None:
#     213     # Caller is responsible for ensuring we have an Index object.
# --> 214     self._validate_set_axis(axis, new_labels)
#     215     self.axes[axis] = new_labels
#
# File ~\.conda\envs\myenv\lib\site-packages\pandas\core\internals\base.py:69, in DataManager._validate_set_axis(self, axis, new_labels)
#      66     pass
#      68 elif new_len != old_len:
# ---> 69     raise ValueError(
#      70         f"Length mismatch: Expected axis has {old_len} elements, new "
#      71         f"values have {new_len} elements"
#      72     )
#
# ValueError: Length mismatch: Expected axis has 25 elements, new values have 19 elements

# %%
data2=pd.read_csv(r"C:\Workplace\Python\AnalysisForThePaper\NEH\second_round\D2O_NEH\res_theo_2.csv")
data2.columns=['pep','a','b','cpxt','pxt','neh','cneh','b1','b2','b3','a1','a2','delta1','delta2','rmse',
             'a20','a21','a22','a23']
data2=data2[data2.pxt<=0.06]

# data2.a=data2.a20 +data2.a21 +data2.a22 +data2.a23 

# data2.pxt=[(abs(x)) for x in data2.pxt]
# data2.cpxt=[(abs(x)) for x in data2.cpxt]
# data2.a=[(abs(x)) for x in data2.a]
# data2.a20=[(abs(x)) for x in data2.a20]
# data2.a21=[(abs(x)) for x in data2.a21]
# data2.a22=[(abs(x)) for x in data2.a22]
# data2.a23=[(abs(x)) for x in data2.a23]

data2=data2.drop_duplicates()
print(data2.shape)

# %%
pep=list(np.unique(data.pep))
len(pep)

# %%
# index=10
# temp1=data[data.pep==pep[index]]
# temp2=data2[data2.pep==pep[index]]
# # temp2=temp1
# print(pep[index],temp1.shape[0],temp2.shape[0])

# plt.figure(figsize=(15,10))
# plt.subplot(2,3,1)
# plt.title('pxt')
# plt.scatter(temp.pxt,temp.cpxt_y,s=10,c='k')
# plt.plot(temp.pxt,temp.pxt,c='r',ls="-.")
# plt.subplot(2,3,2)
# plt.title('a')
# plt.scatter(temp.a_x,temp.a_y,s=10,c='k')
# plt.subplot(2,3,3)
# plt.title('a1')
# plt.scatter(temp.a20_x,temp.a20_y,s=10,c='k')
# plt.subplot(2,3,4)
# plt.title('a2')
# plt.scatter(temp.a21_x,temp.a21_y,s=10,c='k')
# plt.subplot(2,3,5)
# plt.title('a3')
# plt.scatter(temp.a22_x,temp.a22_y,s=10,c='k')
# plt.subplot(2,3,6)
# plt.title('a4')
# plt.scatter(temp.a23_x,temp.a23_y,s=10,c='k')
# plt.show()

# plt.figure(figsize=(15,10))
# plt.subplot(2,3,1)
# plt.title('a')
# plt.scatter(temp.pxt,temp.a_x,s=10,c='g')
# plt.scatter(temp.pxt,temp.a_y,s=10,c='r')
# plt.subplot(2,3,2)
# plt.title('a1')
# plt.scatter(temp.pxt,temp.a20_x,s=10,c='g')
# plt.scatter(temp.pxt,temp.a20_y,s=10,c='r')
# plt.subplot(2,3,3)
# plt.title('a2')
# plt.scatter(temp.pxt,temp.a21_x,s=10,c='g')
# plt.scatter(temp.pxt,temp.a21_y,s=10,c='r')
# plt.subplot(2,3,4)
# plt.title('a3')
# plt.scatter(temp.pxt,temp.a22_x,s=10,c='g')
# plt.scatter(temp.pxt,temp.a22_y,s=10,c='r')
# plt.subplot(2,3,5)
# plt.title('a4')
# plt.scatter(temp.pxt,temp.a23_x,s=10,c='g')
# plt.scatter(temp.pxt,temp.a23_y,s=10,c='r')

# %%
# temp_merge=temp1.merge(temp2, on=['pep','pxt'])
# temp_merge['pxt_acc']=100*abs(temp_merge.cpxt_y-temp_merge.pxt)/temp_merge.pxt

# temp=temp_merge[temp_merge.pxt_acc<20]
# plt.figure(figsize=(15,10))
# plt.subplot(2,3,1)
# plt.title('pxt')
# plt.scatter(temp.pxt,temp.cpxt_y,s=10,c='k')
# plt.plot(temp.pxt,temp.pxt,c='r',ls="-.")
# plt.subplot(2,3,2)
# plt.title('a')
# plt.scatter(temp.a_x,temp.a_y,s=10,c='k')
# plt.subplot(2,3,3)
# plt.title('a1')
# plt.scatter(temp.a20_x,temp.a20_y,s=10,c='k')
# plt.subplot(2,3,4)
# plt.title('a2')
# plt.scatter(temp.a21_x,temp.a21_y,s=10,c='k')
# plt.subplot(2,3,5)
# plt.title('a3')
# plt.scatter(temp.a22_x,temp.a22_y,s=10,c='k')
# plt.subplot(2,3,6)
# plt.title('a4')
# plt.scatter(temp.a23_x,temp.a23_y,s=10,c='k')
# plt.show()
# print('===================================================')

# temp=temp_merge[temp_merge.pxt_acc>20]

# plt.figure(figsize=(15,10))
# plt.subplot(2,3,1)
# plt.title('pxt')
# plt.scatter(temp.pxt,temp.cpxt_y,s=10,c='k')
# plt.plot(temp.pxt,temp.pxt,c='r',ls="-.")
# plt.subplot(2,3,2)
# plt.title('a')
# plt.scatter(temp.a_x,temp.a_y,s=10,c='k')
# plt.subplot(2,3,3)
# plt.title('a1')
# plt.scatter(temp.a20_x,temp.a20_y,s=10,c='k')
# plt.subplot(2,3,4)
# plt.title('a2')
# plt.scatter(temp.a21_x,temp.a21_y,s=10,c='k')
# plt.subplot(2,3,5)
# plt.title('a3')
# plt.scatter(temp.a22_x,temp.a22_y,s=10,c='k')
# plt.subplot(2,3,6)
# plt.title('a4')
# plt.scatter(temp.a23_x,temp.a23_y,s=10,c='k')
# plt.show()
# print('===================================================')

# plt.figure(figsize=(15,10))
# plt.subplot(2,3,1)
# plt.title('a')
# plt.scatter(temp_merge.pxt,temp_merge.a_x,s=10,c='g')
# plt.scatter(temp.pxt,temp.a_y,s=10,c='r')
# plt.subplot(2,3,2)
# plt.title('a1')
# plt.scatter(temp_merge.pxt,temp_merge.a20_x,s=10,c='g')
# plt.scatter(temp.pxt,temp.a20_y,s=10,c='r')
# plt.subplot(2,3,3)
# plt.title('a2')
# plt.scatter(temp_merge.pxt,temp_merge.a21_x,s=10,c='g')
# plt.scatter(temp.pxt,temp.a21_y,s=10,c='r')
# plt.subplot(2,3,4)
# plt.title('a3')
# plt.scatter(temp_merge.pxt,temp_merge.a22_x,s=10,c='g')
# plt.scatter(temp_merge.pxt,temp_merge.a22_y,s=10,c='r')
# plt.subplot(2,3,5)
# plt.title('a4')
# plt.scatter(temp_merge.pxt,temp_merge.a22_x,s=10,c='g')
# plt.scatter(temp_merge.pxt,temp_merge.a22_y,s=10,c='r')

# %%
index=1

while index < len(pep):
    temp1=data[data.pep==pep[index]]
    temp2=data2[data2.pep==pep[index]]

    temp_merge=temp1.merge(temp2, on=['pep','pxt'])
    temp_merge['pxt_acc']=100*abs(temp_merge.cpxt_y-temp_merge.pxt)/temp_merge.pxt
    

    temp=temp_merge#[temp_merge.pxt_acc<20]
#     if temp.shape[0]<10:
#         index+=1
#         continue
    print(f"=================================={pep[index]}========================")
    plt.figure(figsize=(15,10))
    plt.subplot(2,3,1)
    plt.title('pxt')
    plt.scatter(temp.pxt,temp.cpxt_y,s=10,c='k')
    plt.plot(temp.pxt,temp.pxt,c='r',ls="-.")
    plt.subplot(2,3,2)
    plt.title('a')
    plt.scatter(temp.a_x,temp.a_y,s=10,c='k')
    plt.subplot(2,3,3)
    plt.title('a1')
    plt.scatter(temp.a20_x,temp.a20_y,s=10,c='k')
    plt.subplot(2,3,4)
    plt.title('a2')
    plt.scatter(temp.a21_x,temp.a21_y,s=10,c='k')
    plt.subplot(2,3,5)
    plt.title('a3')
    plt.scatter(temp.a22_x,temp.a22_y,s=10,c='k')
    plt.subplot(2,3,6)
    plt.title('a4')
    plt.scatter(temp.a23_x,temp.a23_y,s=10,c='k')
    plt.show()
    print('===================================================')

#     temp=temp_merge[temp_merge.pxt_acc>20]

#     plt.figure(figsize=(15,10))
#     plt.subplot(2,3,1)
#     plt.title('pxt')
#     plt.scatter(temp.pxt,temp.cpxt_y,s=10,c='k')
#     plt.plot(temp.pxt,temp.pxt,c='r',ls="-.")
#     plt.subplot(2,3,2)
#     plt.title('a')
#     plt.scatter(temp.a_x,temp.a_y,s=10,c='k')
#     plt.subplot(2,3,3)
#     plt.title('a1')
#     plt.scatter(temp.a20_x,temp.a20_y,s=10,c='k')
#     plt.subplot(2,3,4)
#     plt.title('a2')
#     plt.scatter(temp.a21_x,temp.a21_y,s=10,c='k')
#     plt.subplot(2,3,5)
#     plt.title('a3')
#     plt.scatter(temp.a22_x,temp.a22_y,s=10,c='k')
#     plt.subplot(2,3,6)
#     plt.title('a4')
#     plt.scatter(temp.a23_x,temp.a23_y,s=10,c='k')
#     plt.show()
#     print('===================================================')

    plt.figure(figsize=(15,10))
    plt.subplot(2,3,1)
    plt.title('a')
    plt.plot(temp_merge.pxt,temp_merge.a_x,c='g')#,ls='-.',alpha=0.75)
    plt.scatter(temp.pxt,temp.a_y,s=10,c='r')
    plt.xlabel('pxt')
    plt.subplot(2,3,2)
    plt.title('a1')
    plt.plot(temp_merge.pxt,temp_merge.a20_x,c='g',ls='-.',alpha=0.75)
    plt.scatter(temp.pxt,temp.a20_y,s=10,c='r')
    plt.xlabel('pxt')
    plt.subplot(2,3,3)
    plt.title('a2')
    plt.plot(temp_merge.pxt,temp_merge.a21_x,c='g',ls='-.',alpha=0.75)
    plt.scatter(temp.pxt,temp.a21_y,s=10,c='r')
    plt.xlabel('pxt')
    plt.subplot(2,3,4)
    plt.title('a3')
    plt.plot(temp_merge.pxt,temp_merge.a22_x,c='g',ls='-.',alpha=0.75)
    plt.scatter(temp_merge.pxt,temp_merge.a22_y,s=10,c='r')
    plt.xlabel('pxt')
    plt.subplot(2,3,5)
    plt.title('a4')
    plt.plot(temp_merge.pxt,temp_merge.a23_x,c='g',ls='-.',alpha=0.75)
    plt.scatter(temp_merge.pxt,temp_merge.a23_y,s=10,c='r')
    plt.xlabel('pxt')
    plt.show()
    
    index+=1
    print("********************************************************\n")
    
    if i ==25:
        break
