# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
s = np.random.uniform(0,2,20)
# s=[int(10*x) for x in s]

# %%
np.random.seed(seed=5)
s = np.random.uniform(0,2,20)
s=[int(10*x) for x in s]
count, bins, ignored = plt.hist(s, 15, density=False)

plt.plot(bins, np.ones_like(bins), linewidth=2, color='r')


plt.show()
s
# Out:
# [4, 17, 4, 18, 9, 12, 15, 10, 5, 3, 1, 14, 8, 3, 17, 5, 8, 5, 12, 11]

# %%
res=[]
for i in range(100):
    np.random.seed(seed=i)
    s = np.random.uniform(0,2,20)
    s=[int(10*x) for x in s]
    res.append(s)

# %%
s=np.array(res).ravel()
count, bins, ignored = plt.hist(s, 15, density=False)

plt.plot(bins, np.ones_like(bins), linewidth=2, color='r')


plt.show()

# %%
s=[(10*x) for x in np.array(np.random.uniform(low = 0, high = 2, size = (20, 1000))).ravel()]#np.rint
count, bins, ignored = plt.hist(s, 20, density=False)

# plt.plot(bins, np.ones_like(bins), linewidth=2, color='r')


plt.show()

# %%
# import pandas as pd
# pd.DataFrame(np.unique(s,return_counts=True)).transpose()

# %%
# np.random.uniform(low = 0, high = 20, size = (20, 1000))

# %%
bins.shape
# Out:
# (21,)

# %%
np.ones_like(bins).shape
# Out:
# (21,)

# %%
count.shape
# Out:
# (20,)

# %%
bins
# Out:
# array([4.85000773e-04, 1.00045297e+00, 2.00042094e+00, 3.00038891e+00,
#        4.00035688e+00, 5.00032485e+00, 6.00029283e+00, 7.00026080e+00,
#        8.00022877e+00, 9.00019674e+00, 1.00001647e+01, 1.10001327e+01,
#        1.20001007e+01, 1.30000686e+01, 1.40000366e+01, 1.50000046e+01,
#        1.59999725e+01, 1.69999405e+01, 1.79999085e+01, 1.89998764e+01,
#        1.99998444e+01])

# %%
count
# Out:
# array([ 999., 1044.,  983., 1029.,  994., 1033.,  995.,  957., 1013.,
#         970.,  987., 1058., 1031., 1014.,  949.,  963.,  997.,  986.,
#        1000.,  998.])

# %%
s
# Out:
# [18.40682289056827,
#  9.275670862302547,
#  4.12138208863861,
#  18.05853236943613,
#  13.660757155670042,
#  10.013901789696178,
#  2.7272272320582136,
#  13.717945274606842,
#  9.034606306372252,
#  19.766096078015952,
#  15.289121564729484,
#  3.1599759949813744,
#  3.201982053268555,
#  4.342773079813926,
#  19.234562707159164,
#  8.316328089213634,
#  5.656489060109944,
#  1.982236663917727,
#  5.7685079793023935,
#  2.897587557348762,
#  7.594734114428496,
#  17.193482813596106,
#  11.10702157301425,
#  3.4254245065326416,
#  10.152687342127301,
#  19.973551736817175,
#  10.587099903307145,
#  12.792626205830198,
#  3.5760027084837476,
#  1.1172942826988574,
#  14.912935095290718,
#  15.088231978930303,
#  6.337895425348739,
#  19.859712843907047,
#  18.793949286575845,
#  9.728097655451815,
#  8.582596997509535,
#  7.051121936334734,
#  15.015685282109208,
#  15.090495637080156,
#  8.578129520144419,
#  19.167447813190552,
#  19.009033276932577,
#  14.037524974684661,
# ...
