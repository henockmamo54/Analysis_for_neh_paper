# %%
import os
import math
import random
import warnings
import numpy as np
import pandas as pd 
from sklearn import metrics
from matplotlib import pyplot as plt
import seaborn as sns
warnings.filterwarnings("ignore")

# %%
data0=pd.read_csv(r"C:\Workplace\Python\AnalysisForThePaper\NEH\Final\SNR\test_perprotien\denovo_figure4.csv")
print(data0.shape)
data0.head()
# Out:
# (12524, 6)
#    T_NEH  T_PXT  PXT_THEO  NEH_THEO   PXT_EXP    NEH_EXP
# 0     11  0.046         0         0  0.046001  12.999697
# 1     21  0.046         0         0  0.046000  12.000054
# 2     16  0.046         0         0  0.046000  22.000128
# 3     23  0.046         0         0  0.046000  18.999908
# 4     16  0.046         0         0  0.046000  22.000098

# %%
print(data0.shape)
plt.rc('font', size=15) 
plt.figure(figsize=(8,8))
plt.scatter(data0['T_NEH'],data0['NEH_EXP'],alpha=0.5,
            label=f'n = {data0.shape[0]}\n' + 'r = '+'{0:.2f}'.format(np.corrcoef(data0['T_NEH'],
                                                     data0['NEH_EXP'])[0][1]),c='k')

plt.plot(data0['T_NEH'],data0['T_NEH'],ls="-.",c='r')
# plt.xlabel("NEH (Sim.)")
plt.xlabel(r"Assigned $N_{EH}$")
# plt.ylabel("Estimation of NEH using  \nAtomic percent excess (APE) ")
plt.ylabel(r"$N_{EH}$, residual sum of squares")
plt.legend() 
plt.savefig("denovo_figure4.jpeg",dpi=900,bbox_inches='tight')
plt.show()
# data.columns
print(data0[data0['DataRecord.APE_rmse']<0.01].shape)
# Out:
# (12524, 6)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\hmdebern.UTMB-USERS-M\.conda\envs\myenv\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File c:\Users\hmdebern.UTMB-USERS-M\.conda\envs\myenv\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\hmdebern.UTMB-USERS-M\.conda\envs\myenv\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'DataRecord.APE_rmse'
#
# ...
