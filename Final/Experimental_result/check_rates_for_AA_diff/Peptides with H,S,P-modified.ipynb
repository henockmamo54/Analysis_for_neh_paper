# %%
import os
import math
import random
import warnings
import numpy as np
import pandas as pd 
from sklearn import metrics
from matplotlib import pyplot as plt
import seaborn as sns
from scipy import stats as st
warnings.filterwarnings("ignore")

# %%
NEH_LIVERPOOL={'A' : 3.442,'C' : 1.811,'D' : 2.974,'E' : 4.378,'F' : 0.519,'G' : 1.822,'H' : 1.957,'I' : 0.76,'K' : 0.037,
               'L' : 0.92,'M' : 0.774,'N' : 1.319,'P' : 1.673,'Q' : 3.985,'R' : 1.701,'S' : 1.972,'T' : 0.351,'V' : 0.742,
               'W' : 0.277,'Y' : 0.957}
def get_newNeh(pep):
    res=0
    for c in pep:
        res+=NEH_LIVERPOOL[c.upper()]
    return res
 
def get_aa_count(peps):
    res={}
    
    for pep in peps:
        for c in np.unique(list(pep)):
            res[c.upper()]=  res.get(c.upper(),0)+1
    df=pd.DataFrame([res.keys(),res.values()]).transpose()
    df.columns=['AA','Count']
    df=df.sort_values(by='Count')
    return df

def get_hspr_d_count(peps):
    res=[[],[]]
    scale=20
    for x in peps:
        hsp_count= scale * (x.count('S')+x.count('P')+x.count('H')+x.count('R'))
        d_count= scale *x.count('D')
        
        if hsp_count > d_count:
            res[0].append(hsp_count)
            res[1].append('g')
        else:
            res[0].append(d_count)
            res[1].append('r')
            
    return res   
    
def q_filter(df,col):
    q_low = df[col].quantile(0.05)
    q_hi  = df[col].quantile(0.95)

    df_filtered = df[(df[col] < q_hi) & (df[col] > q_low)]
    return df_filtered

# %%
prots=['CPSM_MOUSE', 'AL1L1_MOUSE', 'FAS_MOUSE', 'SARDH_MOUSE', 'PYC_MOUSE', 'DHE3_MOUSE', 'THIM_MOUSE', 'HYES_MOUSE',
       'ATPB_MOUSE', 'HMCS2_MOUSE', 'ASSY_MOUSE', 'ECHA_MOUSE', 'ATPA_MOUSE', 'CH60_MOUSE', 'FAAA_MOUSE', 'M2GD_MOUSE',
       'PYGL_MOUSE', 'DHSO_MOUSE', 'EF2_MOUSE', 'CAH3_MOUSE', 'AL1A1_MOUSE', 'BHMT1_MOUSE', 'ADH1_MOUSE', 'SBP1_MOUSE',
       'SAHH_MOUSE', 'ALDH2_MOUSE', 'PGM1_MOUSE', 'EST1D_MOUSE', 'CLH1_MOUSE', 'ARGI1_MOUSE']

for prot_name in prots:
    
    data_original=pd.read_csv(r'C:\Workplace\Python\AnalysisForThePaper\NEH\d2ome_output\liverpool_liver\\'+f'{prot_name}.RateConst.csv')
    data_original=data_original.dropna()

    data_modified=pd.read_csv(r'C:\Workplace\executables_test\d2ome_4_1_2024\test_output\test\liverpool_liver_modified\\'+f'{prot_name}.RateConst.csv')
    data_modified=data_modified.dropna()

    data_original.columns=[x.strip() for x in data_original.columns]
    data_modified.columns=[x.strip() for x in data_modified.columns]
    
#     normal=[x for x in data_original.Peptides if  ((x.count('S')+x.count('P')+x.count('H')+x.count('R')) <=1) and 'D' not in x]
#     under_estimate=[x for x in data_original.Peptides if  ((x.count('S')+x.count('P')+x.count('H')+x.count('R')) >=1) and 'D' not in x  ]
    
    under_estimate =list(data_original.Peptides)
    

    merged=pd.merge(data_original[['Peptides', 'RateConstants', 'Charge', 'NEH','Rsquared','NDP']]
                    ,data_modified[['Peptides', 'RateConstants', 'Charge', 'NEH','Rsquared']]
                    ,on=['Peptides','Charge'],
                   suffixes=['_orginal','_modi'])
    merged['NEH_modi']=[get_newNeh(x) for x in merged.Peptides]
    
    
    merged=merged[merged.Rsquared_orginal>0.95]
    merged=merged[merged.NDP>9]    
#     merged=merged[merged.NEH_modi < merged.NEH_orginal]
    
    res=get_hspr_d_count(merged.Peptides)

    try:
        plt.figure(figsize=(16,5))
        plt.subplot(1,2,1)

        x=merged.query(f'Peptides in {under_estimate}').RateConstants_orginal
        y=merged.query(f'Peptides in {under_estimate}').RateConstants_modi    
        print(prot_name)    
        print(f'original k - mode {st.mode(x)[0]}, medain {np.median(x)}, mean {np.mean(x)}. SD {np.std(x)} ')
        print(f'modified k - mode {st.mode(y)[0]}, medain {np.median(y)}, mean {np.mean(y)}. SD {np.std(y)} ')

        plt.scatter(x,y,c='k',alpha=0.5)
        plt.plot(x,x,ls=':',c='r')
        plt.xlabel('k (original)')
        plt.ylabel('k (modified)')


        plt.subplot(1,2,2)
    #     sns.kdeplot(x,color='green',label=f'original n ={x.shape[0]}',bw=0.75)
    #     sns.kdeplot(y,color='blue',label=f'modified n ={y.shape[0]}',bw=0.75)
        sns.histplot(x,color='green',label=f'original n ={x.shape[0]}',alpha=0.15,kde=True,bins=x.shape[0]//5)
        sns.histplot(y,color='blue',label=f'modified n ={y.shape[0]}',alpha=0.15,kde=True,bins=x.shape[0]//5)
        plt.legend()
        plt.xlabel('k')
        plt.show()

        #===================================================
        plt.figure(figsize=(16,5))
        plt.subplot(1,2,1)

        plt.scatter(merged.NEH_orginal,merged.NEH_modi,alpha=0.5,s=res[0],c=res[1])    
        plt.plot(merged.NEH_orginal,merged.NEH_orginal,ls=':',c='m')
        plt.xlabel('NEH (original)')
        plt.ylabel('NEH (modified)')

        plt.subplot(1,2,2)
        res=get_aa_count(merged.Peptides)
        plt.bar(range(res.shape[0]),res.Count,color='k')
        plt.xticks(range(res.shape[0]),res.AA)

        plt.show()
       
    except:
        continue
    print("==========================================================")
#     break
# Out:
# CPSM_MOUSE
# original k - mode [0.09798], medain 0.10491, mean 0.10495071942446042. SD 0.019226574409166218
# modified k - mode [0.11203], medain 0.11561, mean 0.11368338129496403. SD 0.019046412285282106
# ==========================================================
# AL1L1_MOUSE
# original k - mode [0.13087], medain 0.21472, mean 0.21727224489795918. SD 0.04125540416129084
# modified k - mode [0.14353], medain 0.24066, mean 0.23765183673469387. SD 0.041512741622718306
# ==========================================================
# FAS_MOUSE
# original k - mode [0.20447], medain 0.270085, mean 0.2757074137931035. SD 0.03968380081040385
# modified k - mode [0.21321], medain 0.29453, mean 0.29318068965517236. SD 0.03587026796195293
# ==========================================================
# SARDH_MOUSE
# original k - mode [0.07071], medain 0.10002, mean 0.10159173913043477. SD 0.01238567902060732
# modified k - mode [0.08713], medain 0.107425, mean 0.11041782608695651. SD 0.016191487553252962
# ==========================================================
# PYC_MOUSE
# original k - mode [0.07587], medain 0.12835, mean 0.13024146341463416. SD 0.02112879385023515
# modified k - mode [0.09808], medain 0.14041, mean 0.14091048780487805. SD 0.02002077432668615
# ==========================================================
# DHE3_MOUSE
# original k - mode [0.06593], medain 0.10567, mean 0.10818675675675675. SD 0.02390924293216917
# modified k - mode [0.09583], medain 0.11613, mean 0.11922567567567567. SD 0.021214765579603195
# ==========================================================
# THIM_MOUSE
# original k - mode [0.07282], medain 0.10696, mean 0.11017514285714285. SD 0.015964968501857624
# modified k - mode [0.09969], medain 0.11568, mean 0.11864685714285714. SD 0.013431011614155944
# ==========================================================
# HYES_MOUSE
# original k - mode [0.17528], medain 0.24725000000000003, mean 0.24670699999999998. SD 0.038123386274044435
# modified k - mode [0.1656], medain 0.26478999999999997, mean 0.26849300000000004. SD 0.037494384659572694
# ==========================================================
# ATPB_MOUSE
# original k - mode [0.06851], medain 0.10173499999999999, mean 0.0975755. SD 0.012488127551798948
# modified k - mode [0.07316], medain 0.106455, mean 0.10451150000000001. SD 0.014254674943680755
# ==========================================================
# HMCS2_MOUSE
# original k - mode [0.11514], medain 0.20350000000000001, mean 0.20526823529411767. SD 0.043953357863467594
# modified k - mode [0.133], medain 0.23249999999999998, mean 0.2290364705882353. SD 0.032930882419926394
# ==========================================================
# ASSY_MOUSE
# original k - mode [0.0867], medain 0.179645, mean 0.19032763157894736. SD 0.04605361123243732
# modified k - mode [0.19528], medain 0.19687, mean 0.20141973684210523. SD 0.04339089005084399
# ==========================================================
# ECHA_MOUSE
# original k - mode [0.07616], medain 0.133465, mean 0.13336617647058824. SD 0.02254467056035063
# modified k - mode [0.10365], medain 0.14335, mean 0.14155735294117647. SD 0.017537577186752876
# ==========================================================
# ATPA_MOUSE
# original k - mode [0.06148], medain 0.10575, mean 0.10552941176470589. SD 0.024565258818714894
# modified k - mode [0.08095], medain 0.11561, mean 0.11641029411764706. SD 0.019679299438345944
# ==========================================================
# CH60_MOUSE
# original k - mode [0.09651], medain 0.10963500000000001, mean 0.1127434375. SD 0.022739329449405356
# modified k - mode [0.08987], medain 0.11433, mean 0.117705625. SD 0.019698156312441397
# ==========================================================
# FAAA_MOUSE
# original k - mode [0.09003], medain 0.140495, mean 0.14287399999999997. SD 0.032312407585941345
# modified k - mode [0.11638], medain 0.166625, mean 0.1612776666666667. SD 0.02759467964219834
# ==========================================================
# M2GD_MOUSE
# original k - mode [0.05957], medain 0.11187, mean 0.1145548484848485. SD 0.025832994772508222
# modified k - mode [0.06278], medain 0.11992, mean 0.12276454545454546. SD 0.02238543832574678
# ==========================================================
# PYGL_MOUSE
# original k - mode [0.07814], medain 0.12573499999999999, mean 0.13047289473684212. SD 0.03727295215934915
# modified k - mode [0.08951], medain 0.1278, mean 0.13201342105263159. SD 0.02656156297679192
# ==========================================================
# DHSO_MOUSE
# original k - mode [0.12637], medain 0.172385, mean 0.17657666666666666. SD 0.03233377216197056
# modified k - mode [0.13042], medain 0.197085, mean 0.19811366666666666. SD 0.03675280791842834
# ==========================================================
# EF2_MOUSE
# original k - mode [0.18516], medain 0.24081, mean 0.24177719999999997. SD 0.03369466409032741
# modified k - mode [0.17595], medain 0.25707, mean 0.253962. SD 0.03271847465882235
# ==========================================================
# CAH3_MOUSE
# original k - mode [0.10146], medain 0.13343, mean 0.13603689655172413. SD 0.02171718548847945
# modified k - mode [0.10143], medain 0.14238, mean 0.14355655172413795. SD 0.01697188918748152
# ==========================================================
# AL1A1_MOUSE
# original k - mode [0.12633], medain 0.19227, mean 0.20285451612903221. SD 0.046122421728007644
# modified k - mode [0.13376], medain 0.21533, mean 0.21382999999999996. SD 0.030385213296878044
# ==========================================================
# BHMT1_MOUSE
# original k - mode [0.13884], medain 0.178695, mean 0.17967214285714286. SD 0.025834353285768108
# modified k - mode [0.16396], medain 0.19452, mean 0.19733607142857146. SD 0.018534145773850128
# ==========================================================
# ADH1_MOUSE
# original k - mode [0.09629], medain 0.13915, mean 0.14773406249999999. SD 0.02855464726399354
# modified k - mode [0.14614], medain 0.156975, mean 0.16610312500000002. SD 0.030646642907248018
# ==========================================================
# SBP1_MOUSE
# original k - mode [0.10543], medain 0.16509, mean 0.16583137931034486. SD 0.032199186831040644
# modified k - mode [0.21238], medain 0.17993, mean 0.1802537931034483. SD 0.025053298139792526
# ==========================================================
# SAHH_MOUSE
# original k - mode [0.15598], medain 0.21759, mean 0.2049644. SD 0.03303686947396802
# modified k - mode [0.16383], medain 0.22873, mean 0.22399600000000003. SD 0.03338680685540323
# ==========================================================
# ALDH2_MOUSE
# original k - mode [0.21903], medain 0.30139, mean 0.32475875. SD 0.12121857332632997
# modified k - mode [0.22771], medain 0.3273, mean 0.3400504166666667. SD 0.10369327338675215
# ==========================================================
# PGM1_MOUSE
# original k - mode [0.09898], medain 0.146925, mean 0.14855749999999998. SD 0.026139929904585947
# modified k - mode [0.11637], medain 0.158755, mean 0.16215375. SD 0.022022903383466495
# ==========================================================
# EST1D_MOUSE
# original k - mode [0.18882], medain 0.21472999999999998, mean 0.23076625000000003. SD 0.03467899349900696
# modified k - mode [0.18543], medain 0.231045, mean 0.23601291666666666. SD 0.02501440243126059
# ==========================================================
# CLH1_MOUSE
# original k - mode [0.09441], medain 0.14182, mean 0.14442407407407407. SD 0.0341847197031027
# modified k - mode [0.11206], medain 0.1522, mean 0.15621703703703704. SD 0.03757734136169618
# ==========================================================
# ARGI1_MOUSE
# original k - mode [0.11078], medain 0.15493, mean 0.1608088461538462. SD 0.032190102196760266
# modified k - mode [0.12311], medain 0.168145, mean 0.16931115384615386. SD 0.02291002456549787
# ==========================================================
