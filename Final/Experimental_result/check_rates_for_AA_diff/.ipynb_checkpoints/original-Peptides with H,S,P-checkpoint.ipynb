# %%
import os
import math
import random
import warnings
import numpy as np
import pandas as pd 
from sklearn import metrics
from matplotlib import pyplot as plt
import seaborn as sns
warnings.filterwarnings("ignore")

# %%
data=pd.read_csv(r"C:\Workplace\C++\temp_sol_dev\test\d2ome_restructure\d2ome_GUI\d2ome_GUI\v2\bin\Release\Estimated_neh_numbers_liverpool_liver_.csv")

# %%
prot_count=pd.DataFrame(np.unique(data.Protein,return_counts=True)).transpose()
prot_count.columns=['Protein','Pep_count']
prot_count=prot_count.sort_values(by='Pep_count',ascending=False)
selected_prot=prot_count.head(30).Protein

# %%
prot_count.head(30)
# Out:
#          Protein Pep_count
# 182   CPSM_MOUSE       130
# 66   AL1L1_MOUSE        50
# 272    FAS_MOUSE        48
# 651  SARDH_MOUSE        45
# 575    PYC_MOUSE        39
# 208   DHE3_MOUSE        37
# 715   THIM_MOUSE        36
# 373   HYES_MOUSE        36
# 111   ATPB_MOUSE        36
# 351  HMCS2_MOUSE        36
# 100   ASSY_MOUSE        35
# 225   ECHA_MOUSE        34
# 110   ATPA_MOUSE        32
# 148   CH60_MOUSE        31
# 268   FAAA_MOUSE        31
# 419   M2GD_MOUSE        31
# 576   PYGL_MOUSE        30
# 213   DHSO_MOUSE        30
# 236    EF2_MOUSE        28
# 129   CAH3_MOUSE        28
# 63   AL1A1_MOUSE        28
# 120  BHMT1_MOUSE        26
# 52    ADH1_MOUSE        26
# 652   SBP1_MOUSE        26
# 648   SAHH_MOUSE        25
# 74   ALDH2_MOUSE        25
# 531   PGM1_MOUSE        25
# 251  EST1D_MOUSE        25
# 152   CLH1_MOUSE        25
# 92   ARGI1_MOUSE        24

# %%
for prot_name in selected_prot:
# prot_name='CPSM_MOUSE'

    temp_data=data[data.Protein==prot_name]
    temp_data=temp_data[temp_data.APE_RMSE<0.01]
    
    normal=[x for x in temp_data.Peptide if  'S' not in x and 'P' not in x and 'H' not in x ]
    under_estimate=[x for x in temp_data.Peptide if  ('S' in x or 'P' in x or 'H' in x) ]

    temp_data_normal=temp_data.query(f'Peptide in {normal}')
    temp_data_under_estimate=temp_data.query(f'Peptide in {under_estimate}')
    
    if temp_data_normal.shape[0]<2:
        continue

    print(prot_name)
    
    plt.figure(figsize=(15,5))
    plt.subplot(1,3,1)
    plt.scatter(temp_data_normal.T_NEH ,temp_data_normal.APE_NEH,c='g',alpha=0.8,label='Peptied without [H,S,P]')
    plt.plot(range(1,max(temp_data.T_NEH)) , range(1,max(temp_data.T_NEH)) ,ls=':' ,c='r')
    plt.xlabel('true NEH')
    plt.ylabel('estimated NEH')
    plt.legend()

    plt.subplot(1,3,2)
    plt.scatter(temp_data_under_estimate.T_NEH, temp_data_under_estimate.APE_NEH,c='b',alpha=0.5,label='Peptied with [H,S,P]')
    plt.plot(range(1,max(temp_data.T_NEH)) , range(1,max(temp_data.T_NEH)) ,ls=':' ,c='r')
    plt.xlabel('true NEH')
    plt.ylabel('estimated NEH')
    plt.legend()

    plt.subplot(1,3,3)
    sns.kdeplot(temp_data_normal.two_param_k,color='green',label='Peptied without [H,S,P]')
    sns.kdeplot(temp_data_under_estimate.two_param_k,color='blue',label='Peptied with [H,S,P]')
#     sns.histplot(temp_data_normal.two_param_k,color='green',label='Peptied without [H,S,P]',kde=True,alpha=0.1)
#     sns.histplot(temp_data_under_estimate.two_param_k,color='blue',label='Peptied with [H,S,P]',kde=True,alpha=0.1)
    plt.xlabel('k')
    plt.legend()

    plt.show()
# Out:
# CPSM_MOUSE
# AL1L1_MOUSE
# FAS_MOUSE
# SARDH_MOUSE
# PYC_MOUSE
# DHE3_MOUSE
# HYES_MOUSE
# ATPB_MOUSE
# HMCS2_MOUSE
# ASSY_MOUSE
# ECHA_MOUSE
# ATPA_MOUSE
# CH60_MOUSE
# PYGL_MOUSE
# EF2_MOUSE
# CAH3_MOUSE
# BHMT1_MOUSE
# ADH1_MOUSE
# SAHH_MOUSE
# ALDH2_MOUSE
# ARGI1_MOUSE

# %%
prot_name='CPSM_MOUSE'

temp_data=data[data.Protein==prot_name]
temp_data=temp_data[temp_data.APE_RMSE<0.01]

normal=[x for x in temp_data.Peptide if  'S' not in x and 'P' not in x and 'H' not in x ]
under_estimate=[x for x in temp_data.Peptide if  ('S' in x or 'P' in x or 'H' in x) ]

temp_data_normal=temp_data.query(f'Peptide in {normal}')
temp_data_under_estimate=temp_data.query(f'Peptide in {under_estimate}')


print(prot_name)

plt.figure(figsize=(15,5))
plt.subplot(1,3,1)
plt.scatter(temp_data_normal.T_NEH ,temp_data_normal.APE_NEH,c='g',alpha=0.8,label='Peptied without [H,S,P]')
plt.plot(range(1,max(temp_data.T_NEH)) , range(1,max(temp_data.T_NEH)) ,ls=':' ,c='r')
plt.xlabel('true NEH')
plt.ylabel('estimated NEH')
plt.legend()

plt.subplot(1,3,2)
plt.scatter(temp_data_under_estimate.T_NEH, temp_data_under_estimate.APE_NEH,c='b',alpha=0.5,label='Peptied with [H,S,P]')
plt.plot(range(1,max(temp_data.T_NEH)) , range(1,max(temp_data.T_NEH)) ,ls=':' ,c='r')
plt.xlabel('true NEH')
plt.ylabel('estimated NEH')
plt.legend()

plt.subplot(1,3,3)
sns.kdeplot(temp_data_normal.two_param_k,color='green',label='Peptied without [H,S,P]')
sns.kdeplot(temp_data_under_estimate.two_param_k,color='blue',label='Peptied with [H,S,P]')
#     sns.histplot(temp_data_normal.two_param_k,color='green',label='Peptied without [H,S,P]',kde=True,alpha=0.1)
#     sns.histplot(temp_data_under_estimate.two_param_k,color='blue',label='Peptied with [H,S,P]',kde=True,alpha=0.1)
plt.xlabel('k')
plt.legend()

plt.show()
# Out:
# CPSM_MOUSE

# %%
temp_data_normal.sort_values(by='T_NEH')
# Out:
#          Protein        Peptide  Charge  T_NEH   Asym_NEH           MPE_NEH  \
# 1477  CPSM_MOUSE      ETLIDLGTK       2     11  12.197468   15.519169200433
# 1475  CPSM_MOUSE      VVAVDcGIK       2     12  13.653799  12.2921580004261
# 1501  CPSM_MOUSE   TLGVDFIDVATK       2     13  15.816317  21.9567535814589
