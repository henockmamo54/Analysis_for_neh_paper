# %%
import os
import math
import random
import warnings
import numpy as np
import pandas as pd 
from sklearn import metrics
from matplotlib import pyplot as plt
import seaborn as sns
from scipy import stats as st
warnings.filterwarnings("ignore")

# %%
prots=['CPSM_MOUSE', 'AL1L1_MOUSE', 'FAS_MOUSE', 'SARDH_MOUSE', 'PYC_MOUSE', 'DHE3_MOUSE', 'THIM_MOUSE', 'HYES_MOUSE',
       'ATPB_MOUSE', 'HMCS2_MOUSE', 'ASSY_MOUSE', 'ECHA_MOUSE', 'ATPA_MOUSE', 'CH60_MOUSE', 'FAAA_MOUSE', 'M2GD_MOUSE',
       'PYGL_MOUSE', 'DHSO_MOUSE', 'EF2_MOUSE', 'CAH3_MOUSE', 'AL1A1_MOUSE', 'BHMT1_MOUSE', 'ADH1_MOUSE', 'SBP1_MOUSE',
       'SAHH_MOUSE', 'ALDH2_MOUSE', 'PGM1_MOUSE', 'EST1D_MOUSE', 'CLH1_MOUSE', 'ARGI1_MOUSE']

for prot_name in prots:
    
    data_original=pd.read_csv(r'C:\Workplace\Python\AnalysisForThePaper\NEH\d2ome_output\liverpool_liver\\'+f'{prot_name}.RateConst.csv')
    data_original=data_original.dropna()

    data_modified=pd.read_csv(r'C:\Workplace\executables_test\d2ome_4_1_2024\test_output\test\liverpool_liver\\'+f'{prot_name}.RateConst.csv')
    data_modified=data_modified.dropna()

    data_original.columns=[x.strip() for x in data_original.columns]
    data_modified.columns=[x.strip() for x in data_modified.columns]
    
    normal=[x for x in data_original.Peptides if  ((x.count('S')+x.count('P')+x.count('H')+x.count('R')) <=1) and 'D' not in x]
    under_estimate=[x for x in data_original.Peptides if  ((x.count('S')+x.count('P')+x.count('H')+x.count('R')) >1) and 'D' not in x  ]


    merged=pd.merge(data_original[['Peptides', 'RateConstants', 'Charge', 'NEH','Rsquared']]
                    ,data_modified[['Peptides', 'RateConstants', 'Charge', 'NEH','Rsquared']]
                    ,on=['Peptides','Charge'],
                   suffixes=['_orginal','_modi'])
    merged=merged[merged.Rsquared_orginal>0.75]

    plt.figure(figsize=(16,5))
    plt.subplot(1,2,1)

    x=merged.query(f'Peptides in {under_estimate}').RateConstants_orginal
    y=merged.query(f'Peptides in {under_estimate}').RateConstants_modi
    
    print(prot_name)
    
    print(f'original k - mode {st.mode(x)[0]}, medain {np.median(x)}, mean {np.mean(x)}. SD {np.std(x)} ')
    print(f'modified k - mode {st.mode(y)[0]}, medain {np.median(y)}, mean {np.mean(y)}. SD {np.std(y)} ')
    
    plt.scatter(x,y,c='k',alpha=0.5)
    plt.plot(x,x,ls=':',c='r')
    plt.xlabel('k (original)')
    plt.ylabel('k (modified)')


    plt.subplot(1,2,2)
    sns.kdeplot(x,color='green',label=f'original n ={x.shape[0]}',bw=0.75)
    sns.kdeplot(y,color='blue',label=f'modified n ={y.shape[0]}',bw=0.75)
    plt.legend()
    plt.xlabel('k')
    plt.show()
# Out:
# CPSM_MOUSE
# original k - mode [0.04818], medain 0.10086500000000001, mean 0.09959431818181819. SD 0.01868456356044248
# modified k - mode [0.11203], medain 0.11857999999999999, mean 0.11467909090909094. SD 0.021721043819947956
# AL1L1_MOUSE
# original k - mode [0.08466], medain 0.18569, mean 0.17596782608695652. SD 0.04138807189606811
# modified k - mode [0.10338], medain 0.23219, mean 0.2114582608695652. SD 0.04718895897505409
# FAS_MOUSE
# original k - mode [0.05605], medain 0.23979, mean 0.23659638888888893. SD 0.10155568926983358
# modified k - mode [0.05953], medain 0.27876, mean 0.2807516666666667. SD 0.13205179313225718
# SARDH_MOUSE
# original k - mode [0.03983], medain 0.095745, mean 0.0943075. SD 0.02568972535372848
# modified k - mode [0.04898], medain 0.106255, mean 0.11048600000000001. SD 0.033652447221561764
# PYC_MOUSE
# original k - mode [0.04804], medain 0.12195500000000001, mean 0.11768549999999997. SD 0.025954711609840708
# modified k - mode [0.05344], medain 0.13916, mean 0.14018400000000003. SD 0.03411471052200209
# DHE3_MOUSE
# original k - mode [0.04427], medain 0.08525, mean 0.08789368421052632. SD 0.02908360710462281
# modified k - mode [0.06472], medain 0.10964, mean 0.11165578947368421. SD 0.031424135597673035
# THIM_MOUSE
# original k - mode [0.06644], medain 0.100295, mean 0.09661785714285713. SD 0.01683204816438461
# modified k - mode [0.0879], medain 0.117475, mean 0.11837285714285715. SD 0.01654122660358114
# HYES_MOUSE
# original k - mode [0.08453], medain 0.197985, mean 0.20078714285714286. SD 0.04617834223785795
# modified k - mode [0.17433], medain 0.23352499999999998, mean 0.24164357142857143. SD 0.043106381795861876
# ATPB_MOUSE
# original k - mode [0.04225], medain 0.10062, mean 0.09493937499999999. SD 0.018533085100958635
# modified k - mode [0.04629], medain 0.11266999999999999, mean 0.10516687499999999. SD 0.020686204255115897
# HMCS2_MOUSE
# original k - mode [0.11514], medain 0.17470999999999998, mean 0.17677555555555557. SD 0.031363933324445245
# modified k - mode [0.133], medain 0.21938, mean 0.21598333333333333. SD 0.0374137428701748
# ASSY_MOUSE
# original k - mode [0.0867], medain 0.157455, mean 0.15307937500000002. SD 0.025559467049595826
# modified k - mode [0.09714], medain 0.17820999999999998, mean 0.174133125. SD 0.02600084198606605
# ECHA_MOUSE
# original k - mode [0.06867], medain 0.112415, mean 0.10740125. SD 0.023842561438266234
# modified k - mode [0.07278], medain 0.12657000000000002, mean 0.12375. SD 0.02127893148163225
# ATPA_MOUSE
# original k - mode [0.04763], medain 0.09018, mean 0.1003526086956522. SD 0.042930792659955606
# modified k - mode [0.05021], medain 0.11026, mean 0.11973826086956522. SD 0.04766893434222388
# CH60_MOUSE
# original k - mode [0.09651], medain 0.10265, mean 0.1073375. SD 0.012336412312743112
# modified k - mode [0.11405], medain 0.131695, mean 0.1347875. SD 0.017513809372892007
# FAAA_MOUSE
# original k - mode [0.07804], medain 0.12409, mean 0.12894363636363637. SD 0.02346541992446342
# modified k - mode [0.11507], medain 0.16866, mean 0.16550636363636365. SD 0.023423020251153573
# M2GD_MOUSE
# original k - mode [0.0475], medain 0.10413, mean 0.10567611111111111. SD 0.04033752927745918
# modified k - mode [0.04881], medain 0.11333499999999999, mean 0.12137222222222221. SD 0.04778401854590153
# PYGL_MOUSE
# original k - mode [0.07129], medain 0.092685, mean 0.091785. SD 0.017318383055778232
# modified k - mode [0.07898], medain 0.10565, mean 0.11297000000000001. SD 0.028631034443996842
# DHSO_MOUSE
# original k - mode [0.07493], medain 0.14623, mean 0.13861099999999998. SD 0.03365324930820202
# modified k - mode [0.13054], medain 0.192025, mean 0.17981600000000003. SD 0.027446270493456857
# EF2_MOUSE
# original k - mode [0.09208], medain 0.19581, mean 0.19464230769230767. SD 0.060418727503449586
# modified k - mode [0.14074], medain 0.22582, mean 0.2284807692307692. SD 0.039913460320960645
# CAH3_MOUSE
# original k - mode [0.07292], medain 0.12018, mean 0.11623153846153847. SD 0.01724812357515754
# modified k - mode [0.08507], medain 0.13496, mean 0.13171538461538465. SD 0.016365826786035972
# AL1A1_MOUSE
# original k - mode [0.11107], medain 0.179525, mean 0.18062714285714285. SD 0.05335234730792364
# modified k - mode [0.13376], medain 0.20811, mean 0.21566642857142856. SD 0.0619414079833449
# BHMT1_MOUSE
# original k - mode [0.15161], medain 0.176805, mean 0.1729175. SD 0.012993493323583155
# modified k - mode [0.17932], medain 0.198635, mean 0.1963125. SD 0.010727025158449102
# ADH1_MOUSE
# original k - mode [0.09629], medain 0.12602, mean 0.1268330769230769. SD 0.021357313063720705
# modified k - mode [0.12825], medain 0.15045, mean 0.15546461538461537. SD 0.025398273598320573
# SBP1_MOUSE
# original k - mode [0.10543], medain 0.14405, mean 0.18050714285714284. SD 0.09051234070781819
# modified k - mode [0.163], medain 0.17431, mean 0.20779428571428568. SD 0.07835127218533994
# SAHH_MOUSE
# original k - mode [0.14235], medain 0.187075, mean 0.185335. SD 0.036320589546426696
# modified k - mode [0.20629], medain 0.224435, mean 0.223545. SD 0.012755834939352265
# ALDH2_MOUSE
# original k - mode [0.16448], medain 0.29256000000000004, mean 0.2753625. SD 0.05966941275687234
# modified k - mode [0.21452], medain 0.319025, mean 0.32036125. SD 0.0821703592296973
# PGM1_MOUSE
# original k - mode [0.09907], medain 0.13275, mean 0.12783400000000003. SD 0.017492020580824847
# modified k - mode [0.1266], medain 0.14102, mean 0.147536. SD 0.019771731942346375
# EST1D_MOUSE
# original k - mode [0.07094], medain 0.20923, mean 0.31259999999999993. SD 0.41739832656370557
# modified k - mode [0.12111], medain 0.2245, mean 0.47976545454545455. SD 0.8473330712231346
# CLH1_MOUSE
# original k - mode [0.09776], medain 0.1253, mean 0.13918181818181818. SD 0.044532050729208066
# modified k - mode [0.10939], medain 0.14445, mean 0.15900272727272727. SD 0.05073440039530451
# ARGI1_MOUSE
# original k - mode [0.13429], medain 0.15416, mean 0.154934. SD 0.016605248086072073
# modified k - mode [0.14985], medain 0.1733, mean 0.169432. SD 0.011641242888970227
