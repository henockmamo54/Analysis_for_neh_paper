# %%
import os
import math
import random
import warnings
import numpy as np
import pandas as pd 
from sklearn import metrics
from matplotlib import pyplot as plt
import seaborn as sns
from scipy import stats as st
warnings.filterwarnings("ignore")

# %%
prots=['CPSM_MOUSE', 'AL1L1_MOUSE', 'FAS_MOUSE', 'SARDH_MOUSE', 'PYC_MOUSE', 'DHE3_MOUSE', 'THIM_MOUSE', 'HYES_MOUSE',
       'ATPB_MOUSE', 'HMCS2_MOUSE', 'ASSY_MOUSE', 'ECHA_MOUSE', 'ATPA_MOUSE', 'CH60_MOUSE', 'FAAA_MOUSE', 'M2GD_MOUSE',
       'PYGL_MOUSE', 'DHSO_MOUSE', 'EF2_MOUSE', 'CAH3_MOUSE', 'AL1A1_MOUSE', 'BHMT1_MOUSE', 'ADH1_MOUSE', 'SBP1_MOUSE',
       'SAHH_MOUSE', 'ALDH2_MOUSE', 'PGM1_MOUSE', 'EST1D_MOUSE', 'CLH1_MOUSE', 'ARGI1_MOUSE']

for prot_name in prots:
    
    data_original=pd.read_csv(r'C:\Workplace\Python\AnalysisForThePaper\NEH\d2ome_output\liverpool_liver\\'+f'{prot_name}.RateConst.csv')
    data_original=data_original.dropna()

    data_modified=pd.read_csv(r'C:\Workplace\executables_test\d2ome_4_1_2024\test_output\test\liverpool_liver\\'+f'{prot_name}.RateConst.csv')
    data_modified=data_modified.dropna()

    data_original.columns=[x.strip() for x in data_original.columns]
    data_modified.columns=[x.strip() for x in data_modified.columns]
    
#     normal=[x for x in data_original.Peptides if  ((x.count('S')+x.count('P')+x.count('H')+x.count('R')) <=1) and 'D' not in x]
    under_estimate=[x for x in data_original.Peptides if  ((x.count('S')+x.count('P')+x.count('H')+x.count('R')) <= 1) and 'D'  in x  ]


    merged=pd.merge(data_original[['Peptides', 'RateConstants', 'Charge', 'NEH','Rsquared']]
                    ,data_modified[['Peptides', 'RateConstants', 'Charge', 'NEH','Rsquared']]
                    ,on=['Peptides','Charge'],
                   suffixes=['_orginal','_modi'])
    merged=merged[merged.Rsquared_orginal>0.75]

    plt.figure(figsize=(16,5))
    plt.subplot(1,2,1)

    x=merged.query(f'Peptides in {under_estimate}').RateConstants_orginal
    y=merged.query(f'Peptides in {under_estimate}').RateConstants_modi
    
    print(prot_name)
    
    print(f'original k - mode {st.mode(x)[0]}, medain {np.median(x)}, mean {np.mean(x)}. SD {np.std(x)} ')
    print(f'modified k - mode {st.mode(y)[0]}, medain {np.median(y)}, mean {np.mean(y)}. SD {np.std(y)} ')
    
    plt.scatter(x,y,c='k',alpha=0.5)
    plt.plot(x,x,ls=':',c='r')
    plt.xlabel('k (original)')
    plt.ylabel('k (modified)')


    plt.subplot(1,2,2)
    sns.kdeplot(x,color='green',label=f'original n ={x.shape[0]}',bw=0.75)
    sns.kdeplot(y,color='blue',label=f'modified n ={y.shape[0]}',bw=0.75)
    plt.legend()
    plt.xlabel('k')
    plt.show()
# Out:
# CPSM_MOUSE
# original k - mode [0.06933], medain 0.115965, mean 0.12307249999999999. SD 0.027976077317653617
# modified k - mode [0.06933], medain 0.11671000000000001, mean 0.12077333333333333. SD 0.027002231337839883
# AL1L1_MOUSE
# original k - mode [0.19687], medain 0.24421, mean 0.24749222222222222. SD 0.030468578998253913
# modified k - mode [0.19258], medain 0.24464, mean 0.2463733333333333. SD 0.032517526897898545
# FAS_MOUSE
# original k - mode [0.01804], medain 0.285545, mean 0.2618957142857143. SD 0.0913295741269173
# modified k - mode [0.01769], medain 0.276335, mean 0.25759499999999996. SD 0.08458829949061682
# SARDH_MOUSE
# original k - mode [0.09998], medain 0.105295, mean 0.105295. SD 0.005315
# modified k - mode [0.0916], medain 0.101105, mean 0.101105. SD 0.009505
# PYC_MOUSE
# original k - mode [0.07177], medain 0.12835, mean 0.12972444444444442. SD 0.031102492258520985
# modified k - mode [0.07177], medain 0.13483, mean 0.13252999999999998. SD 0.030577984818420518
# DHE3_MOUSE
# original k - mode [0.09879], medain 0.11615, mean 0.12077. SD 0.015141476810403929
# modified k - mode [0.09879], medain 0.11615, mean 0.120658. SD 0.018225116076447903
# THIM_MOUSE
# original k - mode [0.12233], medain 0.1416, mean 0.13871333333333333. SD 0.012368056525672189
# modified k - mode [0.11498], medain 0.12887, mean 0.13033333333333333. SD 0.013174046033352432
# HYES_MOUSE
# original k - mode [0.12156], medain 0.254875, mean 0.28087375000000003. SD 0.13357519286318661
# modified k - mode [0.12156], medain 0.225745, mean 0.25551625. SD 0.12254096192064717
# ATPB_MOUSE
# original k - mode [0.10155], medain 0.109815, mean 0.11083. SD 0.008843627649330336
# modified k - mode [0.09659], medain 0.10852, mean 0.1089425. SD 0.009054129927828516
# HMCS2_MOUSE
# original k - mode [0.20418], medain 0.25500500000000004, mean 0.2717433333333334. SD 0.054464241072060805
# modified k - mode [0.217], medain 0.239405, mean 0.24295333333333335. SD 0.021989045505028695
# ASSY_MOUSE
# original k - mode [0.17563], medain 0.19773000000000002, mean 0.22279375. SD 0.05750881952742117
# modified k - mode [0.18165], medain 0.205115, mean 0.22497625. SD 0.05463175769126872
# ECHA_MOUSE
# original k - mode [0.07907], medain 0.15202, mean 0.14183375. SD 0.027678721040494268
# modified k - mode [0.08201], medain 0.14476499999999998, mean 0.1366625. SD 0.023148308658517584
# ATPA_MOUSE
# original k - mode [0.10049], medain 0.11463999999999999, mean 0.11463999999999999. SD 0.014149999999999996
# modified k - mode [0.11672], medain 0.12696, mean 0.12696. SD 0.010239999999999992
# CH60_MOUSE
# original k - mode [0.05048], medain 0.11224, mean 0.11260428571428571. SD 0.03383002348174636
# modified k - mode [0.05048], medain 0.112955, mean 0.11138964285714284. SD 0.030692760486815462
# FAAA_MOUSE
# original k - mode [0.04866], medain 0.168555, mean 0.15982749999999998. SD 0.07296997100691488
# modified k - mode [0.04122], medain 0.168555, mean 0.15796749999999998. SD 0.07581911743584199
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# M2GD_MOUSE
# original k - mode [0.08124], medain 0.08124, mean 0.08124. SD 0.0
# modified k - mode [0.09286], medain 0.09286, mean 0.09286. SD 0.0
# PYGL_MOUSE
# original k - mode [0.10838], medain 0.13717, mean 0.15367666666666666. SD 0.04859707736982636
# modified k - mode [0.11119], medain 0.12867, mean 0.14052800000000001. SD 0.029395905429157987
# DHSO_MOUSE
# original k - mode [0.1782], medain 0.22675, mean 0.22675. SD 0.048549999999999996
# modified k - mode [0.1782], medain 0.22675, mean 0.22675. SD 0.048549999999999996
# EF2_MOUSE
# original k - mode [0.19235], medain 0.252655, mean 0.25173599999999996. SD 0.03898739621980416
# modified k - mode [0.19356], medain 0.257715, mean 0.262263. SD 0.037506310682337174
# CAH3_MOUSE
# original k - mode [0.13128], medain 0.14218, mean 0.15788000000000002. SD 0.028463374516892553
# modified k - mode [0.13397], medain 0.15196, mean 0.14957444444444445. SD 0.011543177986355894
# AL1A1_MOUSE
# original k - mode [0.13911], medain 0.24103, mean 0.23852272727272725. SD 0.07075388239793039
# modified k - mode [0.13911], medain 0.22358, mean 0.22613000000000003. SD 0.054536962278306754
# BHMT1_MOUSE
# original k - mode [0.15884], medain 0.22021999999999997, mean 0.24408749999999999. SD 0.08389987466468589
# modified k - mode [0.15645], medain 0.22639, mean 0.24345. SD 0.07661590337521317
# ADH1_MOUSE
# original k - mode [0.13434], medain 0.16511, mean 0.15781. SD 0.01383229120572583
# modified k - mode [0.12724], medain 0.18122, mean 0.17192400000000002. SD 0.023786125872028847
# SBP1_MOUSE
# original k - mode [0.19444], medain 0.24781999999999998, mean 0.2478275. SD 0.042071894641791445
# modified k - mode [0.19444], medain 0.21437, mean 0.2154925. SD 0.01578307222152899
# SAHH_MOUSE
# original k - mode [0.14395], medain 0.22208, mean 0.21054428571428568. SD 0.04036974162383889
# modified k - mode [0.10961], medain 0.21705, mean 0.2101971428571429. SD 0.049085399549963854
# ALDH2_MOUSE
# original k - mode [0.29038], medain 0.37700500000000003, mean 0.4549825. SD 0.18074684407687455
# modified k - mode [0.25508], medain 0.35202500000000003, mean 0.415725. SD 0.1709363300325592
# PGM1_MOUSE
# original k - mode [0.04792], medain 0.170545, mean 0.15579666666666667. SD 0.05536690547811231
# modified k - mode [0.04984], medain 0.15009499999999998, mean 0.14734666666666665. SD 0.04900562949521435
# EST1D_MOUSE
# original k - mode [0.29181], medain 0.30351, mean 0.31326. SD 0.02531952902405573
# modified k - mode [0.23356], medain 0.26083, mean 0.2559725. SD 0.013347463008002687
# CLH1_MOUSE
# original k - mode [0.04601], medain 0.14401, mean 0.13108571428571428. SD 0.04422041992988658
# modified k - mode [0.04103], medain 0.13953, mean 0.12039857142857142. SD 0.04052060690159353
# ARGI1_MOUSE
# original k - mode [0.13861], medain 0.19166499999999997, mean 0.18338000000000002. SD 0.030062849997962594
# modified k - mode [0.12231], medain 0.17113499999999998, mean 0.1632275. SD 0.02665586649782745
